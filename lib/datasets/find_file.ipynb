# %%
import pandas as pd 
import numpy as np
import math
import matplotlib.pyplot as plt
import os 
a = pd.read_csv(r'C:\Users\89457\Desktop\optimizaiton\Spatial-Temporal\spatial-temporal\grin-main\datasets/discharge\SSC_discharge.csv',index_col=0)
b = (a - a.mean())/a.std() + 1
c = a.transform(lambda x: np.log10(x+1))

data = b.values
plt.plot(data[0:1500,0])

# %%
import pandas as pd 
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/zhuoliu/DiGress-main/grin-main/lib/datasets/find_file.ipynb 单元格 2 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Blambda02.ece.rochester.edu/home/zhuoliu/DiGress-main/grin-main/lib/datasets/find_file.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell://ssh-remote%2Blambda02.ece.rochester.edu/home/zhuoliu/DiGress-main/grin-main/lib/datasets/find_file.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import numpy as np
# ----> <a href='vscode-notebook-cell://ssh-remote%2Blambda02.ece.rochester.edu/home/zhuoliu/DiGress-main/grin-main/lib/datasets/find_file.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> df_target = pd.read_csv('.../grin/datasets/discharge/pooled.csv',index_col=0)
# ...
